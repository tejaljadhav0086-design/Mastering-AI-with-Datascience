# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataset
df = pd.read_csv('/content/USA_Housing - USA_Housing.csv')

# %%
# number of columns
print("Number of columns:", df.shape[1])
# Out:
# Number of columns: 7

# %%
#checking missing values
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0                False                False                      False
# 1                False                False                      False
# 2                False                False                      False
# 3                False                False                      False
# 4                False                False                      False
# ...                ...                  ...                        ...
# 4995             False                False                      False
# 4996             False                False                      False
# 4997             False                False                      False
# 4998             False                False                      False
# 4999             False                False                      False
#
#       Avg. Area Number of Bedrooms  Area Population  Price  Address
# ...

# %%
#checking missing values
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0                False                False                      False
# 1                False                False                      False
# 2                False                False                      False
# 3                False                False                      False
# 4                False                False                      False
# ...                ...                  ...                        ...
# 4995             False                False                      False
# 4996             False                False                      False
# 4997             False                False                      False
# 4998             False                False                      False
# 4999             False                False                      False
#
#       Avg. Area Number of Bedrooms  Area Population  Price  Address
# ...

# %%
#checking datatypes
print(df.dtypes)
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
#checking datatypes
print(df.dtypes)
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
#calculating mean numeric columns
print(df.mean(numeric_only=True))
# Out:
# Avg. Area Income                6.858311e+04
# Avg. Area House Age             5.977222e+00
# Avg. Area Number of Rooms       6.987792e+00
# Avg. Area Number of Bedrooms    3.981330e+00
# Area Population                 3.616352e+04
# Price                           1.232073e+06
# dtype: float64

# %%
#correlation between columns
print(df.corr(numeric_only=True))
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
#grouped data by categorical columns
grouped_data = df.groupby('Address').mean(numeric_only=True)
print(grouped_data)
# Out:
#                                                   Avg. Area Income  \
# Address
# 000 Adkins Crescent\nSouth Teresa, AS 49642-1348       46621.53501
# 000 Todd Pines\nAshleyberg, KY 90207-1179              64754.56545
# 001 Steve Plaza\nJessicastad, UT 25190                 66263.91050
# 0010 Gregory Loaf\nSouth Ericfort, VA 34651-0718       62212.55965
# 00149 Raymond Knolls\nNew Jason, UT 75026              78555.12950
# ...                                                            ...
# Unit 9774 Box 4511\nDPO AE 44963                       62845.10684
# Unit 9778 Box 2114\nDPO AP 59374                       73853.70376
# Unit 9785 Box 0790\nDPO AP 60371-0797                  61606.92174
# Unit 9831 Box 7128\nDPO AA 54705                       68001.19526
# Unit 9871 Box 9037\nDPO AP 37275-9289                  49623.97434
#
#                                                   Avg. Area House Age  \
# Address
# 000 Adkins Crescent\nSouth Teresa, AS 49642-1348             7.091212
# ...

# %%
#performing EDA
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
#correlation
plt.figure(figsize=(6, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
df.hist(figsize=(6, 8), bins=25)
plt.tight_layout()
plt.show()

# %%
#Boxplot
df.boxplot(figsize=(6, 8))
plt.show()
