# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/student_habits_performance.csv')   #load dataset

# %%
# number of columns
print("Number of columns:", df.shape[1])
# Out:
# Number of columns: 16

# %%
#checking missing values
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of      student_id    age  gender  study_hours_per_day  social_media_hours  \
# 0         False  False   False                False               False
# 1         False  False   False                False               False
# 2         False  False   False                False               False
# 3         False  False   False                False               False
# 4         False  False   False                False               False
# ..          ...    ...     ...                  ...                 ...
# 995       False  False   False                False               False
# 996       False  False   False                False               False
# 997       False  False   False                False               False
# 998       False  False   False                False               False
# 999       False  False   False                False               False
#
#      netflix_hours  part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
#checking datatypes
print(df.dtypes)
# Out:
# student_id                        object
# age                                int64
# gender                            object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating               int64
# extracurricular_participation     object
# exam_score                       float64
# dtype: object

# %%
#calculating mean numeric columns
print(df.mean(numeric_only=True))
# Out:
# age                      20.4980
# study_hours_per_day       3.5501
# social_media_hours        2.5055
# netflix_hours             1.8197
# attendance_percentage    84.1317
# sleep_hours               6.4701
# exercise_frequency        3.0420
# mental_health_rating      5.4380
# exam_score               69.6015
# dtype: float64

# %%
#correlation between columns
print(df.corr(numeric_only=True))
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.003971           -0.009151
# study_hours_per_day    0.003971             1.000000            0.020282
# social_media_hours    -0.009151             0.020282            1.000000
# netflix_hours         -0.001174            -0.031158            0.011477
# attendance_percentage -0.026055             0.026264            0.040479
# sleep_hours            0.037482            -0.027757            0.018236
# exercise_frequency    -0.003836            -0.028701           -0.037319
# mental_health_rating  -0.045101            -0.003768            0.001496
# exam_score            -0.008907             0.825419           -0.166733
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                        -0.001174              -0.026055     0.037482
# study_hours_per_day        -0.031158               0.026264    -0.027757
# ...

# %%
#grouped data by categorical columns
grouped_data = df.groupby('parental_education_level').mean(numeric_only=True)
print(grouped_data)
# Out:
#                                 age  study_hours_per_day  social_media_hours  \
# parental_education_level
# Bachelor                  20.600000             3.505143            2.447143
# High School               20.364796             3.551276            2.547194
# Master                    20.473054             3.579641            2.525150
#
#                           netflix_hours  attendance_percentage  sleep_hours  \
# parental_education_level
# Bachelor                       1.816286              84.551143     6.515143
# High School                    1.855612              83.822704     6.437500
# Master                         1.800599              82.609581     6.473653
#
#                           exercise_frequency  mental_health_rating  exam_score
# parental_education_level
# Bachelor                            3.068571              5.734286   70.272571
# High School                         3.117347              5.477041   69.547194
# ...

# %%
#grouped data by categorical columns
grouped_data = df.groupby('student_id').mean(numeric_only=True)
print(grouped_data)
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# student_id
# S1000       23.0                  0.0                 1.2            1.1
# S1001       20.0                  6.9                 2.8            2.3
# S1002       21.0                  1.4                 3.1            1.3
# S1003       23.0                  1.0                 3.9            1.0
# S1004       19.0                  5.0                 4.4            0.5
# ...          ...                  ...                 ...            ...
# S1995       21.0                  2.6                 0.5            1.6
# S1996       17.0                  2.9                 1.0            2.4
# S1997       20.0                  3.0                 2.6            1.3
# S1998       24.0                  5.4                 4.1            1.1
# S1999       19.0                  4.3                 2.9            1.9
#
#             attendance_percentage  sleep_hours  exercise_frequency  \
# ...

# %%
#performing EDA
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
#correlation
plt.figure(figsize=(6, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
df.hist(figsize=(6, 8), bins=25)
plt.tight_layout()
plt.show()

# %%
#Boxplot
df.boxplot(figsize=(6, 8))
plt.show()
